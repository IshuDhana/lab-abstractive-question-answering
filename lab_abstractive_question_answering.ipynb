# %% [markdown]
# <a href="https://colab.research.google.com/github/IshuDhana/lab-abstractive-question-answering/blob/main/lab_abstractive_question_answering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB | Abstractive Question Answering

# %% [markdown]
# Abstractive question-answering focuses on the generation of multi-sentence answers to open-ended questions. It usually works by searching massive document stores for relevant information and then using this information to synthetically generate answers. This notebook demonstrates how Pinecone helps you build an abstractive question-answering system. We need three main components:
#
# - A vector index to store and run semantic search
# - A retriever model for embedding context passages
# - A generator model to generate answers

# %% [markdown]
# # Install Dependencies

# %%
import torch
from sentence_transformers import SentenceTransformer
# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Load a small, lightweight model
retriever = SentenceTransformer("all-MiniLM-L6-v2", device=device)
print("Retriever loaded successfully on", device)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Retriever loaded successfully on cuda

# %%
# !pip install -qU datasets==2.16.1 pinecone-client==3.1.0 sentence-transformers torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.0/211.0 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 750.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 99.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 62.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 13.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.9.1 which is incompatible.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.9.1 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2023.10.0 which is incompatible.

# %% [markdown]
# # Load and Prepare Dataset

# %% [markdown]
# Our source data will be taken from the Wiki Snippets dataset, which contains over 17 million passages from Wikipedia. But, since indexing the entire dataset may take some time, we will only utilize 50,000 passages in this demo that include "History" in the "section title" column. If you want, you may utilize the complete dataset. Pinecone vector database can effortlessly manage millions of documents for you.

# %%
from google.colab import userdata
import os

# Retrieve the API keys
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')

# Set as environment variables
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
os.environ['PINECONE_API_KEY'] = PINECONE_API_KEY

print("OpenAI API key loaded and set as environment variable.")
# Out:
# OpenAI API key loaded and set as environment variable.

# %%
from datasets import load_dataset
# load the SQuAD dataset which contains Wikipedia contexts
# We will use streaming mode and shuffle it
wiki_data = load_dataset(
    'squad',
    split='train',
    streaming=True
).shuffle(seed=960)
# Out:
# README.md: 0.00B [00:00, ?B/s]

# %%
#from datasets import load_dataset

# load the dataset from huggingface in streaming mode and shuffle it
#wiki_data = load_dataset(
#    'vblagoje/wikipedia_snippets_streamed',
#    split='train',
#    streaming=True
#).shuffle(seed=960)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1451297137.py in <cell line: 0>()
#       2
#       3 # load the dataset from huggingface in streaming mode and shuffle it
# ----> 4 wiki_data = load_dataset(
#       5     'vblagoje/wikipedia_snippets_streamed',
#       6     split='train',
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390         increase_load_count(name, resource_type="dataset")
#    1391
# -> 1392     def download_loading_script(self) -> str:
#    1393         file_path = hf_hub_url(self.name, self.name.split("/")[-1] + ".py", revision=self.revision)
#    1394         download_config = self.download_config.copy()
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1130                 metadata_patterns = None
#    1131             if metadata_patterns is not None:
# -> 1132                 metadata_data_files_list = DataFilesList.from_patterns(
#    1133                     metadata_patterns, download_config=self.download_config, base_path=base_path
#    1134                 )
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1029         # Collect metadata files if the module supports them
#    1030         supports_metadata = module_name in _MODULE_SUPPORTS_METADATA
# -> 1031         if self.data_files is None and supports_metadata:
#    1032             try:
#    1033                 metadata_patterns = get_metadata_patterns(base_path)
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     987     from the data files extensions."""
#     988
# --> 989     def __init__(
#     990         self,
#     991         path: str,
#
# RuntimeError: Dataset scripts are no longer supported, but found wikipedia_snippets_streamed.py

# %% [markdown]
# We are loading the dataset in the streaming mode so that we don't have to wait for the whole dataset to download (which is over 9GB). Instead, we iteratively download records one at a time.

# %%
# show the contents of a single document in the dataset
next(iter(wiki_data))
# Out:
# {'id': '56bf8c8aa10cfb140055116f',
#  'title': 'Beyoncé',
#  'context': 'In July 2002, Beyoncé continued her acting career playing Foxxy Cleopatra alongside Mike Myers in the comedy film, Austin Powers in Goldmember, which spent its first weekend atop the US box office and grossed $73 million. Beyoncé released "Work It Out" as the lead single from its soundtrack album which entered the top ten in the UK, Norway, and Belgium. In 2003, Beyoncé starred opposite Cuba Gooding, Jr., in the musical comedy The Fighting Temptations as Lilly, a single mother whom Gooding\'s character falls in love with. The film received mixed reviews from critics but grossed $30 million in the U.S. Beyoncé released "Fighting Temptation" as the lead single from the film\'s soundtrack album, with Missy Elliott, MC Lyte, and Free which was also used to promote the film. Another of Beyoncé\'s contributions to the soundtrack, "Summertime", fared better on the US charts.',
#  'question': "How did the critics view the movie, ''The Fighting Temptations''?",
#  'answers': {'text': ['mixed reviews'], 'answer_start': [545]}}

# %%
history = wiki_data.filter(lambda x: 'title' in x and 'History' in x['title'])
history
# Out:
# IterableDataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_shards: 1
# })

# %%
# filter only documents with History as section_title - Replace None with your code
#history = #

# %% [markdown]
# Let's iterate through the dataset and apply our filter to select the 50,000 historical passages. We will extract `article_title`, `section_title` and `passage_text` from each document.

# %%
from tqdm.auto import tqdm
docs = []
total_doc_count = 50000
for d in tqdm(history, desc="Collecting historical passages"):
    extracted_doc = {
        "id": d.get("id"),  # Add this line to include the document ID
        "article_title": d.get("title"),
        "section_title": "History",
        "passage_text": d.get("context")
    }
    if extracted_doc["passage_text"]:
        docs.append(extracted_doc)
        tqdm.write(f"Collected {len(docs)} valid passages")  # optional logging
    if len(docs) >= total_doc_count:
        break
# Out:
# Collecting historical passages: 0it [00:00, ?it/s]
# Collected 1 valid passages
# Collected 2 valid passages
# Collected 3 valid passages
# Collected 4 valid passages
# Collected 5 valid passages
# Collected 6 valid passages
# Collected 7 valid passages
# Collected 8 valid passages
# Collected 9 valid passages
# Collected 10 valid passages
# Collected 11 valid passages
# Collected 12 valid passages
# Collected 13 valid passages
# Collected 14 valid passages
# Collected 15 valid passages
# Collected 16 valid passages
# Collected 17 valid passages
# Collected 18 valid passages
# Collected 19 valid passages
# Collected 20 valid passages
# Collected 21 valid passages
# Collected 22 valid passages
# Collected 23 valid passages
# Collected 24 valid passages
# Collected 25 valid passages
# Collected 26 valid passages
# Collected 27 valid passages
# Collected 28 valid passages
# Collected 29 valid passages
# Collected 30 valid passages
# Collected 31 valid passages
# Collected 32 valid passages
# Collected 33 valid passages
# Collected 34 valid passages
# Collected 35 valid passages
# Collected 36 valid passages
# Collected 37 valid passages
# Collected 38 valid passages
# Collected 39 valid passages
# Collected 40 valid passages
# Collected 41 valid passages
# Collected 42 valid passages
# Collected 43 valid passages
# Collected 44 valid passages
# Collected 45 valid passages
# Collected 46 valid passages
# Collected 47 valid passages
# Collected 48 valid passages
# Collected 49 valid passages
# Collected 50 valid passages
# Collected 51 valid passages
# Collected 52 valid passages
# Collected 53 valid passages
# Collected 54 valid passages
# Collected 55 valid passages
# Collected 56 valid passages
# Collected 57 valid passages
# Collected 58 valid passages
# Collected 59 valid passages
# Collected 60 valid passages
# Collected 61 valid passages
# Collected 62 valid passages
# Collected 63 valid passages
# Collected 64 valid passages
# Collected 65 valid passages
# Collected 66 valid passages
# Collected 67 valid passages
# Collected 68 valid passages
# Collected 69 valid passages
# Collected 70 valid passages
# Collected 71 valid passages
# Collected 72 valid passages
# Collected 73 valid passages
# Collected 74 valid passages
# Collected 75 valid passages
# Collected 76 valid passages
# Collected 77 valid passages
# Collected 78 valid passages
# Collected 79 valid passages
# Collected 80 valid passages
# Collected 81 valid passages
# Collected 82 valid passages
# Collected 83 valid passages
# Collected 84 valid passages
# Collected 85 valid passages
# Collected 86 valid passages
# Collected 87 valid passages
# Collected 88 valid passages
# Collected 89 valid passages
# Collected 90 valid passages
# Collected 91 valid passages
# Collected 92 valid passages
# Collected 93 valid passages
# Collected 94 valid passages
# Collected 95 valid passages
# Collected 96 valid passages
# Collected 97 valid passages
# Collected 98 valid passages
# Collected 99 valid passages
# Collected 100 valid passages
# Collected 101 valid passages
# Collected 102 valid passages
# Collected 103 valid passages
# Collected 104 valid passages
# Collected 105 valid passages
# Collected 106 valid passages
# Collected 107 valid passages
# Collected 108 valid passages
# Collected 109 valid passages
# Collected 110 valid passages
# Collected 111 valid passages
# Collected 112 valid passages
# Collected 113 valid passages
# Collected 114 valid passages
# Collected 115 valid passages
# Collected 116 valid passages
# Collected 117 valid passages
# Collected 118 valid passages
# Collected 119 valid passages
# Collected 120 valid passages
# Collected 121 valid passages
# Collected 122 valid passages
# Collected 123 valid passages
# Collected 124 valid passages
# Collected 125 valid passages
# Collected 126 valid passages
# Collected 127 valid passages
# Collected 128 valid passages
# Collected 129 valid passages
# Collected 130 valid passages
# Collected 131 valid passages
# Collected 132 valid passages
# Collected 133 valid passages
# Collected 134 valid passages
# Collected 135 valid passages
# Collected 136 valid passages
# Collected 137 valid passages
# Collected 138 valid passages
# Collected 139 valid passages
# Collected 140 valid passages
# Collected 141 valid passages
# Collected 142 valid passages
# Collected 143 valid passages
# Collected 144 valid passages
# Collected 145 valid passages
# Collected 146 valid passages
# Collected 147 valid passages
# Collected 148 valid passages
# Collected 149 valid passages
# Collected 150 valid passages
# Collected 151 valid passages
# Collected 152 valid passages
# Collected 153 valid passages
# Collected 154 valid passages
# Collected 155 valid passages
# Collected 156 valid passages
# Collected 157 valid passages
# Collected 158 valid passages
# Collected 159 valid passages
# Collected 160 valid passages
# Collected 161 valid passages
# Collected 162 valid passages
# Collected 163 valid passages
# Collected 164 valid passages
# Collected 165 valid passages
# Collected 166 valid passages
# Collected 167 valid passages
# Collected 168 valid passages
# Collected 169 valid passages
# Collected 170 valid passages
# Collected 171 valid passages
# Collected 172 valid passages
# Collected 173 valid passages
# Collected 174 valid passages
# Collected 175 valid passages
# Collected 176 valid passages
# Collected 177 valid passages
# Collected 178 valid passages
# Collected 179 valid passages
# Collected 180 valid passages
# Collected 181 valid passages
# Collected 182 valid passages
# Collected 183 valid passages
# Collected 184 valid passages
# Collected 185 valid passages
# Collected 186 valid passages
# Collected 187 valid passages
# Collected 188 valid passages
# Collected 189 valid passages
# Collected 190 valid passages
# Collected 191 valid passages
# Collected 192 valid passages
# Collected 193 valid passages
# Collected 194 valid passages
# Collected 195 valid passages
# Collected 196 valid passages
# Collected 197 valid passages
# Collected 198 valid passages
# Collected 199 valid passages
# Collected 200 valid passages
# Collected 201 valid passages
# Collected 202 valid passages
# Collected 203 valid passages
# Collected 204 valid passages
# Collected 205 valid passages
# Collected 206 valid passages
# Collected 207 valid passages
# Collected 208 valid passages
# Collected 209 valid passages
# Collected 210 valid passages
# Collected 211 valid passages
# Collected 212 valid passages
# Collected 213 valid passages
# Collected 214 valid passages
# Collected 215 valid passages
# Collected 216 valid passages
# Collected 217 valid passages
# Collected 218 valid passages
# Collected 219 valid passages
# Collected 220 valid passages
# Collected 221 valid passages
# Collected 222 valid passages
# Collected 223 valid passages
# Collected 224 valid passages
# Collected 225 valid passages
# Collected 226 valid passages
# Collected 227 valid passages
# Collected 228 valid passages
# Collected 229 valid passages
# Collected 230 valid passages
# Collected 231 valid passages
# Collected 232 valid passages
# Collected 233 valid passages
# Collected 234 valid passages
# Collected 235 valid passages
# Collected 236 valid passages
# Collected 237 valid passages
# Collected 238 valid passages
# Collected 239 valid passages
# Collected 240 valid passages
# Collected 241 valid passages
# Collected 242 valid passages
# Collected 243 valid passages
# Collected 244 valid passages
# Collected 245 valid passages
# Collected 246 valid passages
# Collected 247 valid passages
# Collected 248 valid passages
# Collected 249 valid passages
# Collected 250 valid passages
# Collected 251 valid passages
# Collected 252 valid passages
# Collected 253 valid passages
# Collected 254 valid passages
# Collected 255 valid passages
# Collected 256 valid passages
# Collected 257 valid passages
# Collected 258 valid passages
# Collected 259 valid passages
# Collected 260 valid passages
# Collected 261 valid passages
# Collected 262 valid passages
# Collected 263 valid passages
# Collected 264 valid passages
# Collected 265 valid passages
# Collected 266 valid passages
# Collected 267 valid passages
# Collected 268 valid passages
# Collected 269 valid passages
# Collected 270 valid passages
# Collected 271 valid passages
# Collected 272 valid passages
# Collected 273 valid passages
# Collected 274 valid passages
# Collected 275 valid passages
# Collected 276 valid passages
# Collected 277 valid passages
# Collected 278 valid passages
# Collected 279 valid passages
# Collected 280 valid passages
# Collected 281 valid passages
# Collected 282 valid passages
# Collected 283 valid passages
# Collected 284 valid passages
# Collected 285 valid passages
# Collected 286 valid passages
# Collected 287 valid passages
# Collected 288 valid passages
# Collected 289 valid passages
# Collected 290 valid passages
# Collected 291 valid passages
# Collected 292 valid passages
# Collected 293 valid passages
# Collected 294 valid passages
# Collected 295 valid passages
# Collected 296 valid passages
# Collected 297 valid passages
# Collected 298 valid passages
# Collected 299 valid passages
# Collected 300 valid passages
# Collected 301 valid passages
# Collected 302 valid passages
# Collected 303 valid passages
# Collected 304 valid passages
# Collected 305 valid passages
# Collected 306 valid passages
# Collected 307 valid passages
# Collected 308 valid passages
# Collected 309 valid passages
# Collected 310 valid passages
# Collected 311 valid passages
# Collected 312 valid passages
# Collected 313 valid passages
# Collected 314 valid passages
# Collected 315 valid passages
# Collected 316 valid passages
# Collected 317 valid passages
# Collected 318 valid passages
# Collected 319 valid passages
# Collected 320 valid passages
# Collected 321 valid passages
# Collected 322 valid passages
# Collected 323 valid passages
# Collected 324 valid passages
# Collected 325 valid passages
# Collected 326 valid passages
# Collected 327 valid passages
# Collected 328 valid passages
# Collected 329 valid passages
# Collected 330 valid passages
# Collected 331 valid passages
# Collected 332 valid passages
# Collected 333 valid passages
# Collected 334 valid passages
# Collected 335 valid passages
# Collected 336 valid passages
# Collected 337 valid passages
# Collected 338 valid passages
# Collected 339 valid passages
# Collected 340 valid passages
# Collected 341 valid passages
# Collected 342 valid passages
# Collected 343 valid passages
# Collected 344 valid passages
# Collected 345 valid passages
# Collected 346 valid passages
# Collected 347 valid passages
# Collected 348 valid passages
# Collected 349 valid passages
# Collected 350 valid passages
# Collected 351 valid passages
# Collected 352 valid passages
# Collected 353 valid passages
# Collected 354 valid passages
# Collected 355 valid passages
# Collected 356 valid passages
# Collected 357 valid passages
# Collected 358 valid passages
# Collected 359 valid passages
# Collected 360 valid passages
# Collected 361 valid passages
# Collected 362 valid passages
# Collected 363 valid passages
# Collected 364 valid passages
# Collected 365 valid passages
# Collected 366 valid passages
# Collected 367 valid passages
# Collected 368 valid passages
# Collected 369 valid passages
# Collected 370 valid passages
# Collected 371 valid passages
# Collected 372 valid passages
# Collected 373 valid passages
# Collected 374 valid passages
# Collected 375 valid passages
# Collected 376 valid passages
# Collected 377 valid passages
# Collected 378 valid passages
# Collected 379 valid passages
# Collected 380 valid passages
# Collected 381 valid passages
# Collected 382 valid passages
# Collected 383 valid passages
# Collected 384 valid passages
# Collected 385 valid passages
# Collected 386 valid passages
# Collected 387 valid passages
# Collected 388 valid passages
# Collected 389 valid passages
# Collected 390 valid passages
# Collected 391 valid passages
# Collected 392 valid passages
# Collected 393 valid passages
# Collected 394 valid passages
# Collected 395 valid passages
# Collected 396 valid passages
# Collected 397 valid passages
# Collected 398 valid passages
# Collected 399 valid passages
# Collected 400 valid passages
# Collected 401 valid passages
# Collected 402 valid passages
# Collected 403 valid passages
# Collected 404 valid passages
# Collected 405 valid passages
# Collected 406 valid passages
# Collected 407 valid passages
# Collected 408 valid passages
# Collected 409 valid passages
# Collected 410 valid passages
# Collected 411 valid passages
# Collected 412 valid passages
# Collected 413 valid passages
# Collected 414 valid passages
# Collected 415 valid passages
# Collected 416 valid passages
# Collected 417 valid passages
# Collected 418 valid passages
# Collected 419 valid passages
# Collected 420 valid passages
# Collected 421 valid passages
# Collected 422 valid passages
# Collected 423 valid passages
# Collected 424 valid passages
# Collected 425 valid passages
# Collected 426 valid passages
# Collected 427 valid passages
# Collected 428 valid passages
# Collected 429 valid passages
# Collected 430 valid passages
# Collected 431 valid passages
# Collected 432 valid passages
# Collected 433 valid passages
# Collected 434 valid passages
# Collected 435 valid passages
# Collected 436 valid passages
# Collected 437 valid passages
# Collected 438 valid passages
# Collected 439 valid passages
# Collected 440 valid passages
# Collected 441 valid passages
# Collected 442 valid passages
# Collected 443 valid passages
# Collected 444 valid passages
# Collected 445 valid passages
# Collected 446 valid passages
# Collected 447 valid passages
# Collected 448 valid passages
# Collected 449 valid passages
# Collected 450 valid passages
# Collected 451 valid passages
# Collected 452 valid passages
# Collected 453 valid passages
# Collected 454 valid passages
# Collected 455 valid passages
# Collected 456 valid passages
# Collected 457 valid passages
# Collected 458 valid passages
# Collected 459 valid passages
# Collected 460 valid passages
# Collected 461 valid passages
# Collected 462 valid passages
# Collected 463 valid passages
# Collected 464 valid passages
# Collected 465 valid passages
# Collected 466 valid passages
# Collected 467 valid passages
# Collected 468 valid passages
# Collected 469 valid passages
# Collected 470 valid passages
# Collected 471 valid passages
# Collected 472 valid passages
# Collected 473 valid passages
# Collected 474 valid passages
# Collected 475 valid passages
# Collected 476 valid passages
# Collected 477 valid passages
# Collected 478 valid passages
# Collected 479 valid passages
# Collected 480 valid passages
# Collected 481 valid passages
# Collected 482 valid passages
# Collected 483 valid passages
# Collected 484 valid passages
# Collected 485 valid passages
# Collected 486 valid passages
# Collected 487 valid passages
# Collected 488 valid passages
# Collected 489 valid passages
# Collected 490 valid passages
# Collected 491 valid passages
# Collected 492 valid passages
# Collected 493 valid passages
# Collected 494 valid passages
# Collected 495 valid passages
# Collected 496 valid passages
# Collected 497 valid passages
# Collected 498 valid passages
# Collected 499 valid passages
# Collected 500 valid passages
# Collected 501 valid passages
# Collected 502 valid passages
# Collected 503 valid passages
# Collected 504 valid passages
# Collected 505 valid passages
# Collected 506 valid passages
# Collected 507 valid passages
# Collected 508 valid passages
# Collected 509 valid passages
# Collected 510 valid passages
# Collected 511 valid passages
# Collected 512 valid passages
# Collected 513 valid passages
# Collected 514 valid passages
# Collected 515 valid passages
# Collected 516 valid passages
# Collected 517 valid passages
# Collected 518 valid passages
# Collected 519 valid passages
# Collected 520 valid passages
# Collected 521 valid passages
# Collected 522 valid passages
# Collected 523 valid passages
# Collected 524 valid passages
# Collected 525 valid passages
# Collected 526 valid passages
# Collected 527 valid passages
# Collected 528 valid passages
# Collected 529 valid passages
# Collected 530 valid passages
# Collected 531 valid passages
# Collected 532 valid passages
# Collected 533 valid passages
# Collected 534 valid passages
# Collected 535 valid passages
# Collected 536 valid passages
# Collected 537 valid passages
# Collected 538 valid passages
# Collected 539 valid passages
# Collected 540 valid passages
# Collected 541 valid passages
# Collected 542 valid passages
# Collected 543 valid passages
# Collected 544 valid passages
# Collected 545 valid passages
# Collected 546 valid passages
# Collected 547 valid passages
# Collected 548 valid passages
# Collected 549 valid passages
# Collected 550 valid passages
# Collected 551 valid passages
# Collected 552 valid passages
# Collected 553 valid passages
# Collected 554 valid passages
# Collected 555 valid passages
# Collected 556 valid passages
# Collected 557 valid passages
# Collected 558 valid passages
# Collected 559 valid passages
# Collected 560 valid passages
# Collected 561 valid passages
# Collected 562 valid passages
# Collected 563 valid passages
# Collected 564 valid passages
# Collected 565 valid passages
# Collected 566 valid passages
# Collected 567 valid passages
# Collected 568 valid passages
# Collected 569 valid passages
# Collected 570 valid passages
# Collected 571 valid passages
# Collected 572 valid passages
# Collected 573 valid passages
# Collected 574 valid passages
# Collected 575 valid passages
# Collected 576 valid passages
# Collected 577 valid passages
# Collected 578 valid passages
# Collected 579 valid passages
# Collected 580 valid passages
# Collected 581 valid passages
# Collected 582 valid passages
# Collected 583 valid passages
# Collected 584 valid passages
# Collected 585 valid passages
# Collected 586 valid passages
# Collected 587 valid passages
# Collected 588 valid passages
# Collected 589 valid passages
# Collected 590 valid passages
# Collected 591 valid passages
# Collected 592 valid passages
# Collected 593 valid passages
# Collected 594 valid passages
# Collected 595 valid passages
# Collected 596 valid passages
# Collected 597 valid passages
# Collected 598 valid passages
# Collected 599 valid passages
# Collected 600 valid passages
# Collected 601 valid passages
# Collected 602 valid passages
# Collected 603 valid passages
# Collected 604 valid passages
# Collected 605 valid passages
# Collected 606 valid passages
# Collected 607 valid passages
# Collected 608 valid passages
# Collected 609 valid passages
# Collected 610 valid passages
# Collected 611 valid passages
# Collected 612 valid passages
# Collected 613 valid passages
# Collected 614 valid passages
# Collected 615 valid passages
# Collected 616 valid passages
# Collected 617 valid passages
# Collected 618 valid passages
# Collected 619 valid passages
# Collected 620 valid passages
# Collected 621 valid passages
# Collected 622 valid passages
# Collected 623 valid passages
# Collected 624 valid passages
# Collected 625 valid passages
# Collected 626 valid passages
# Collected 627 valid passages
# Collected 628 valid passages
# Collected 629 valid passages
# Collected 630 valid passages
# Collected 631 valid passages
# Collected 632 valid passages
# Collected 633 valid passages
# Collected 634 valid passages
# Collected 635 valid passages
# Collected 636 valid passages
# Collected 637 valid passages
# Collected 638 valid passages
# Collected 639 valid passages
# Collected 640 valid passages
# Collected 641 valid passages
# Collected 642 valid passages
# Collected 643 valid passages
# Collected 644 valid passages
# Collected 645 valid passages
# Collected 646 valid passages
# Collected 647 valid passages
# Collected 648 valid passages
# Collected 649 valid passages
# Collected 650 valid passages
# Collected 651 valid passages
# Collected 652 valid passages
# Collected 653 valid passages
# Collected 654 valid passages
# Collected 655 valid passages
# Collected 656 valid passages
# Collected 657 valid passages
# Collected 658 valid passages
# Collected 659 valid passages
# Collected 660 valid passages
# Collected 661 valid passages
# Collected 662 valid passages
# Collected 663 valid passages
# Collected 664 valid passages
# Collected 665 valid passages
# Collected 666 valid passages
# Collected 667 valid passages
# Collected 668 valid passages
# Collected 669 valid passages
# Collected 670 valid passages
# Collected 671 valid passages
# Collected 672 valid passages
# Collected 673 valid passages
# Collected 674 valid passages
# Collected 675 valid passages
# Collected 676 valid passages
# Collected 677 valid passages
# Collected 678 valid passages
# Collected 679 valid passages
# Collected 680 valid passages
# Collected 681 valid passages
# Collected 682 valid passages
# Collected 683 valid passages
# Collected 684 valid passages
# Collected 685 valid passages
# Collected 686 valid passages
# Collected 687 valid passages
# Collected 688 valid passages
# Collected 689 valid passages
# Collected 690 valid passages
# Collected 691 valid passages
# Collected 692 valid passages
# Collected 693 valid passages
# Collected 694 valid passages
# Collected 695 valid passages
# Collected 696 valid passages
# Collected 697 valid passages
# Collected 698 valid passages

# %%
import pandas as pd

# create a pandas dataframe with the documents we extracted
df = pd.DataFrame(docs)
df.head()
# Out:
#                          id       article_title section_title  \
# 0  5726ebefdd62a815002e9552  History_of_science       History
# 1  5726fa9cdd62a815002e96bd  History_of_science       History
# 2  5726fa9cdd62a815002e96bf  History_of_science       History
# 3  5726f1c9f1498d1400e8f0a9  History_of_science       History
# 4  5726f997f1498d1400e8f18b  History_of_science       History
#
#                                         passage_text
# 0  The English word scientist is relatively recen...
# 1  The astronomer Aristarchus of Samos was the fi...
# 2  The astronomer Aristarchus of Samos was the fi...
# 3  Ancient Egypt made significant advances in ast...
# 4  The important legacy of this period included s...

# %% [markdown]
# # Initialize Pinecone Index

# %% [markdown]
# The Pinecone index stores vector representations of our historical passages which we can retrieve later using another vector (query vector). To build our vector index, we must first establish a connection with Pinecone. For this, we need an API from Pinecone. You can get one for free from [here](https://app.pinecone.io/), and after that, we initialize the connection as follows:

# %%
import os
from pinecone import Pinecone

# initialize connection to pinecone (get API key at app.pinecone.io)
api_key = os.environ.get('PINECONE_API_KEY') or 'PINECONE_API_KEY'

# configure client
pc = Pinecone(api_key=api_key)

# %% [markdown]
# Now we setup our index specification, this allows us to define the cloud provider and region where we want to deploy our index. You can find a list of all [available providers and regions here](https://docs.pinecone.io/docs/projects).

# %%
from pinecone import ServerlessSpec

cloud = os.environ.get('PINECONE_CLOUD') or 'aws'
region = os.environ.get('PINECONE_REGION') or 'us-east-1'

spec = ServerlessSpec(cloud=cloud, region=region)

# %% [markdown]
# Now we create a new index. We will name it "abstractive-question-answering" — you can name it anything we want. We specify the metric type as "cosine" and dimension as 768 because the retriever we use to generate context embeddings is optimized for cosine similarity and outputs 768-dimension vectors.

# %%
index_name = "abstract-question-answering" #give your index a meaningful name

# %%
# Get the embedding dimension from the retriever model
expected_dimension = retriever.get_sentence_embedding_dimension()

if index_name in pc.list_indexes().names():
    # Check if the existing index has the correct dimension
    existing_index_description = pc.describe_index(index_name)
    if existing_index_description.dimension != expected_dimension:
        print(f"Index '{index_name}' exists with dimension {existing_index_description.dimension}, but retriever outputs {expected_dimension}.")
        print(f"Deleting and recreating index '{index_name}' with the correct dimension.")
        pc.delete_index(index_name)
        pc.create_index(name=index_name, dimension=expected_dimension, metric="cosine", spec=spec)
        print(f"Index '{index_name}' recreated successfully with dimension {expected_dimension}.")
    else:
        print(f"Index '{index_name}' already exists with the correct dimension ({expected_dimension}).")
else:
    print(f"Index '{index_name}' does not exist. Creating it now with dimension {expected_dimension}...")
    pc.create_index(name=index_name, dimension=expected_dimension, metric="cosine", spec=spec)
    print(f"Index '{index_name}' created successfully.")

# Connect to the index
index = pc.Index(index_name)

print(f"Connected to index '{index_name}'.")
# Out:
# Index 'abstract-question-answering' does not exist. Creating it now with dimension 384...
# Index 'abstract-question-answering' created successfully.
# Connected to index 'abstract-question-answering'.

# %%
import time

# check if index already exists (it shouldn't if this is first time)
None #initialize the index, and insure the stats are all zeros

# %% [markdown]
# # Initialize Retriever

# %% [markdown]
# Next, we need to initialize our retriever. The retriever will mainly do two things:
#
# - Generate embeddings for all historical passages (context vectors/embeddings)
# - Generate embeddings for our questions (query vector/embedding)
#
# The retriever will create embeddings such that the questions and passages that hold the answers to our queries are close to one another in the vector space. We will use a SentenceTransformer model based on Microsoft's MPNet as our retriever. This model performs quite well for comparing the similarity between queries and documents. We can use Cosine Similarity to compute the similarity between query and context vectors generated by this model (Pinecone automatically does this for us).

# %%
import time

# 1. Wait for the index to be ready
print(f"Waiting for index '{index_name}' to be ready...")
while True:
    try:
        # describe_index returns an IndexDescription object which has a status field
        index_description = pc.describe_index(index_name)
        if index_description.status.ready:
            print(f"Index '{index_name}' is ready.")
            break
        else:
            # Index is not ready yet, print current state and wait
            print(f"Index '{index_name}' is not ready yet. Status: {index_description.status.state}. Waiting...")
            time.sleep(10) # Wait for 10 seconds before checking again
    except Exception as e:
        # Catch potential errors if index is still being created/initialized by Pinecone
        print(f"Error checking index status: {e}. Retrying in 10 seconds...")
        time.sleep(10)

# 2. Ensure the stats are all zeros (for a freshly created/empty index)
# Use index.describe_index_stats() to get the current statistics
stats = index.describe_index_stats()

# Check if the total_vector_count is 0
if stats.total_vector_count == 0:
    print(f"Index '{index_name}' is empty (total_vector_count: {stats.total_vector_count}).")
    print(f"Dimension: {stats.dimension}")
else:
    print(f"WARNING: Index '{index_name}' is not empty. Current stats:")
    print(stats) # Print full stats if not empty
# Out:
# Waiting for index 'abstract-question-answering' to be ready...
# Index 'abstract-question-answering' is ready.
# Index 'abstract-question-answering' is empty (total_vector_count: 0).
# Dimension: 384

# %%
#import torch
#from sentence_transformers import SentenceTransformer

# set device to GPU if available
#device = 'cuda' if torch.cuda.is_available() else 'cpu'
# load the retriever model from huggingface model hub
#retriever = None #load the retriever model from HuggingFace. Use the flax-sentence-embeddings/all_datasets_v3_mpnet-base model
#retriever
# Out:
# Downloading (…)e933c/.gitattributes:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)cbe6ee933c/README.md:   0%|          | 0.00/9.85k [00:00<?, ?B/s]
# Downloading (…)e6ee933c/config.json:   0%|          | 0.00/591 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)33c/data_config.json:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)e933c/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# Downloading (…)933c/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)cbe6ee933c/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)6ee933c/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %% [markdown]
# # Generate Embeddings and Upsert

# %% [markdown]
# Next, we need to generate embeddings for the context passages. We will do this in batches to help us more quickly generate embeddings and upload them to the Pinecone index. When passing the documents to Pinecone, we need an id (a unique value), context embedding, and metadata for each document representing context passages in the dataset. The metadata is a dictionary containing data relevant to our embeddings, such as the article title, section title, passage text, etc.

# %%
# We will use batches of 64
batch_size = 64

print(f"\nStarting embedding generation and upsert for {len(df)} documents into Pinecone index '{index_name}'...")

# Iterate through the DataFrame in batches
for i in tqdm(range(0, len(df), batch_size), desc="Upserting batches to Pinecone"):
    # Find the end index for the current batch
    i_end = min(i + batch_size, len(df))

    # Extract the current batch of documents from the DataFrame
    batch_df = df.iloc[i:i_end]

    # Extract the 'passage_text' for embedding generation
    batch_texts = batch_df['passage_text'].tolist()

    # Generate embeddings for the current batch of texts
    batch_embeddings = retriever.encode(batch_texts, show_progress_bar=False, device=device).tolist()

    # Prepare records for Pinecone upsert
    vectors_for_batch = []
    for j, row in enumerate(batch_df.itertuples(index=False)):
        # The unique ID for each passage comes from the 'id' column
        doc_id = str(row.id) # Changed from row.wiki_id to row.id

        # Create the metadata dictionary
        metadata = {
            'article_title': row.article_title,
            'section_title': row.section_title,
            'passage_text': row.passage_text, # Common to include the original text in metadata for retrieval
        }
        # Add any other relevant columns from your 'df' to metadata here if you wish

        vectors_for_batch.append({
            'id': doc_id,
            'values': batch_embeddings[j], # 'j' is the index within the current batch_embeddings list
            'metadata': metadata
        })

    # Upsert the prepared batch of vectors to the Pinecone index
    try:
        index.upsert(vectors=vectors_for_batch) # Corrected syntax here
    except Exception as e:
        print(f"\nError upserting batch {i}-{i_end}: {e}")
        # Consider logging the specific batch causing issues or implementing a retry mechanism

print("\nFinished generating embeddings and upserting all batches to Pinecone.")

# Final check: Describe index stats to verify the total number of vectors
print("\nFinal Pinecone Index Statistics:")
final_index_stats = index.describe_index_stats()
if '' in final_index_stats.namespaces:
    print(f"Total vectors in index: {final_index_stats.namespaces[''].vector_count}")
else:
    print(f"Total vectors in index: 0 (No default namespace found, likely empty index).")
print(final_index_stats)
# Out:
# Starting embedding generation and upsert for 698 documents into Pinecone index 'abstract-question-answering'...
# Upserting batches to Pinecone:   0%|          | 0/11 [00:00<?, ?it/s]
# Finished generating embeddings and upserting all batches to Pinecone.
#
# Final Pinecone Index Statistics:
# Total vectors in index: 698
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 698}},
#  'total_vector_count': 698}

# %% [markdown]
# # Initialize Generator

# %% [markdown]
# We will use ELI5 BART for the generator which is a Sequence-To-Sequence model trained using the ‘Explain Like I’m 5’ (ELI5) dataset. Sequence-To-Sequence models can take a text sequence as input and produce a different text sequence as output.
#
# The input to the ELI5 BART model is a single string which is a concatenation of the query and the relevant documents providing the context for the answer. The documents are separated by a special token &lt;P>, so the input string will look as follows:
#
# >question: What is a sonic boom? context: &lt;P> A sonic boom is a sound associated with shock waves created when an object travels through the air faster than the speed of sound. &lt;P> Sonic booms generate enormous amounts of sound energy, sounding similar to an explosion or a thunderclap to the human ear. &lt;P> Sonic booms due to large supersonic aircraft can be particularly loud and startling, tend to awaken people, and may cause minor damage to some structures. This led to prohibition of routine supersonic flight overland.
#
# More detail on how the ELI5 dataset was built is available [here](https://arxiv.org/abs/1907.09190) and how ELI5 BART model was trained is available [here](https://yjernite.github.io/lfqa.html).
#
# Let's initialize the BART model using transformers.

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

# load bart tokenizer and model from huggingface
tokenizer = BartTokenizer.from_pretrained('vblagoje/bart_lfqa')
generator = BartForConditionalGeneration.from_pretrained('vblagoje/bart_lfqa').to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/27.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]

# %% [markdown]
# All the components of our abstract QA system are complete and ready to be queried. But first, let's write some helper functions to retrieve context passages from Pinecone index and to format the query in the way the generator expects the input.

# %%
def query_pinecone(query, top_k):
    # generate embeddings for the query
    xq = retriever.encode(query).tolist()
    # search pinecone index for context passage with the answer
    xc = index.query(vector=xq, top_k=top_k, include_metadata=True)
    return xc

# %%
def format_query(query, context):
    # extract passage_text from Pinecone search result and add the <P> tag
    context = [f"<P> {m['metadata']['passage_text']}" for m in context]
    # concatinate all context passages
    context = " ".join(context)
    # contcatinate the query and context passages
    query = f"question: {query} context: {context}"
    return query

# %% [markdown]
# Let's test the helper functions. We will query the Pinecone index function we created earlier with the `query_pinecone` to get context passages and pass them to the `format_query` function.

# %%
query = "when was the first electric power system built?"
result = query_pinecone(query, top_k=1)
result
# Out:
# {'matches': [{'id': '5727f9a33acd2414000df132',
#               'metadata': {'article_title': 'History_of_science',
#                            'passage_text': 'In 1687, Isaac Newton published '
#                                            'the Principia Mathematica, '
#                                            'detailing two comprehensive and '
#                                            'successful physical theories: '
#                                            "Newton's laws of motion, which led "
#                                            'to classical mechanics; and '
#                                            "Newton's Law of Gravitation, which "
#                                            'describes the fundamental force of '
#                                            'gravity. The behavior of '
#                                            'electricity and magnetism was '
#                                            'studied by Faraday, Ohm, and '
#                                            'others during the early 19th '
#                                            'century. These studies led to the '
#                                            'unification of the two phenomena '
#                                            'into a single theory of '
#                                            'electromagnetism, by James Clerk '
#                                            "Maxwell (known as Maxwell's "
#                                            'equations).',
#                            'section_title': 'History'},
#               'score': 0.255710632,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 1}}

# %%
from pprint import pprint

# %%
# format the query in the form generator expects the input
query = format_query(query, result["matches"])
pprint(query)
# Out:
# ('question: when was the first electric power system built? context: <P> In '
#  '1687, Isaac Newton published the Principia Mathematica, detailing two '
#  "comprehensive and successful physical theories: Newton's laws of motion, "
#  "which led to classical mechanics; and Newton's Law of Gravitation, which "
#  'describes the fundamental force of gravity. The behavior of electricity and '
#  'magnetism was studied by Faraday, Ohm, and others during the early 19th '
#  'century. These studies led to the unification of the two phenomena into a '
#  'single theory of electromagnetism, by James Clerk Maxwell (known as '
#  "Maxwell's equations).")

# %% [markdown]
# The output looks great. Now let's write a function to generate answers.

# %%
def generate_answer(query):
    # tokenize the query to get input_ids
    inputs = tokenizer([query], max_length=1024, return_tensors="pt").to(device)
    # use generator to predict output ids
    ids = generator.generate(inputs["input_ids"], num_beams=2, min_length=20, max_length=40)
    # use tokenizer to decode the output ids
    answer = tokenizer.batch_decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
    return pprint(answer)

# %%
generate_answer(query)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ('The first electric power system was built in the early 19th century. The '
#  'first electric generator was built in the early 19th century. The first '
#  'electric generator was built in the early 20th')

# %% [markdown]
# As we can see, the generator used the provided context to answer our question. Let's run some more queries.

# %%
query = "How was the first wireless message sent?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('The first wireless message was sent in the early 1900s. It was sent by a '
#  'telegraph operator to a telegraph office in New York City. The telegraph '
#  'operator would then send a')

# %% [markdown]
# To confirm that this answer is correct, we can check the contexts used to generate the answer.

# %%
for doc in context["matches"]:
    print(doc["metadata"]["passage_text"], end='\n---\n')
# Out:
# In 1938 Otto Hahn and Fritz Strassmann discovered nuclear fission with radiochemical methods, and in 1939 Lise Meitner and Otto Robert Frisch wrote the first theoretical interpretation of the fission process, which was later improved by Niels Bohr and John A. Wheeler. Further developments took place during World War II, which led to the practical application of radar and the development and use of the atomic bomb. Though the process had begun with the invention of the cyclotron by Ernest O. Lawrence in the 1930s, physics in the postwar period entered into a phase of what historians have called "Big Science", requiring massive machines, budgets, and laboratories in order to test their theories and move into new frontiers. The primary patron of physics became state governments, who recognized that the support of "basic" research could often lead to technologies useful to both military and industrial applications. Currently, general relativity and quantum mechanics are inconsistent with each other, and efforts are underway to unify the two.
# ---
# In 1938 Otto Hahn and Fritz Strassmann discovered nuclear fission with radiochemical methods, and in 1939 Lise Meitner and Otto Robert Frisch wrote the first theoretical interpretation of the fission process, which was later improved by Niels Bohr and John A. Wheeler. Further developments took place during World War II, which led to the practical application of radar and the development and use of the atomic bomb. Though the process had begun with the invention of the cyclotron by Ernest O. Lawrence in the 1930s, physics in the postwar period entered into a phase of what historians have called "Big Science", requiring massive machines, budgets, and laboratories in order to test their theories and move into new frontiers. The primary patron of physics became state governments, who recognized that the support of "basic" research could often lead to technologies useful to both military and industrial applications. Currently, general relativity and quantum mechanics are inconsistent with each other, and efforts are underway to unify the two.
# ---
# In 1938 Otto Hahn and Fritz Strassmann discovered nuclear fission with radiochemical methods, and in 1939 Lise Meitner and Otto Robert Frisch wrote the first theoretical interpretation of the fission process, which was later improved by Niels Bohr and John A. Wheeler. Further developments took place during World War II, which led to the practical application of radar and the development and use of the atomic bomb. Though the process had begun with the invention of the cyclotron by Ernest O. Lawrence in the 1930s, physics in the postwar period entered into a phase of what historians have called "Big Science", requiring massive machines, budgets, and laboratories in order to test their theories and move into new frontiers. The primary patron of physics became state governments, who recognized that the support of "basic" research could often lead to technologies useful to both military and industrial applications. Currently, general relativity and quantum mechanics are inconsistent with each other, and efforts are underway to unify the two.
# ---
# In 1938 Otto Hahn and Fritz Strassmann discovered nuclear fission with radiochemical methods, and in 1939 Lise Meitner and Otto Robert Frisch wrote the first theoretical interpretation of the fission process, which was later improved by Niels Bohr and John A. Wheeler. Further developments took place during World War II, which led to the practical application of radar and the development and use of the atomic bomb. Though the process had begun with the invention of the cyclotron by Ernest O. Lawrence in the 1930s, physics in the postwar period entered into a phase of what historians have called "Big Science", requiring massive machines, budgets, and laboratories in order to test their theories and move into new frontiers. The primary patron of physics became state governments, who recognized that the support of "basic" research could often lead to technologies useful to both military and industrial applications. Currently, general relativity and quantum mechanics are inconsistent with each other, and efforts are underway to unify the two.
# ---
# In 1938 Otto Hahn and Fritz Strassmann discovered nuclear fission with radiochemical methods, and in 1939 Lise Meitner and Otto Robert Frisch wrote the first theoretical interpretation of the fission process, which was later improved by Niels Bohr and John A. Wheeler. Further developments took place during World War II, which led to the practical application of radar and the development and use of the atomic bomb. Though the process had begun with the invention of the cyclotron by Ernest O. Lawrence in the 1930s, physics in the postwar period entered into a phase of what historians have called "Big Science", requiring massive machines, budgets, and laboratories in order to test their theories and move into new frontiers. The primary patron of physics became state governments, who recognized that the support of "basic" research could often lead to technologies useful to both military and industrial applications. Currently, general relativity and quantum mechanics are inconsistent with each other, and efforts are underway to unify the two.
# ---

# %% [markdown]
# In this case, the answer looks correct. If we ask a question and no relevant contexts are retrieved, the generator will typically return nonsensical or false answers, like with this question about COVID-19:

# %%
query = "where did COVID-19 originate?"
context = query_pinecone(query, top_k=3)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('COVID-19 is a strain of the virus that causes the common cold. The virus is '
#  'a type of retrovirus, which means that it is a type of retrovirus that')

# %%
for doc in context["matches"]:
    print(doc["metadata"]["passage_text"], end='\n---\n')
# Out:
# In 1847, Hungarian physician Ignác Fülöp Semmelweis dramatically reduced the occurrency of puerperal fever by simply requiring physicians to wash their hands before attending to women in childbirth. This discovery predated the germ theory of disease. However, Semmelweis' findings were not appreciated by his contemporaries and came into use only with discoveries by British surgeon Joseph Lister, who in 1865 proved the principles of antisepsis. Lister's work was based on the important findings by French biologist Louis Pasteur. Pasteur was able to link microorganisms with disease, revolutionizing medicine. He also devised one of the most important methods in preventive medicine, when in 1880 he produced a vaccine against rabies. Pasteur invented the process of pasteurization, to help prevent the spread of disease through milk and other foods.
# ---
# In 1847, Hungarian physician Ignác Fülöp Semmelweis dramatically reduced the occurrency of puerperal fever by simply requiring physicians to wash their hands before attending to women in childbirth. This discovery predated the germ theory of disease. However, Semmelweis' findings were not appreciated by his contemporaries and came into use only with discoveries by British surgeon Joseph Lister, who in 1865 proved the principles of antisepsis. Lister's work was based on the important findings by French biologist Louis Pasteur. Pasteur was able to link microorganisms with disease, revolutionizing medicine. He also devised one of the most important methods in preventive medicine, when in 1880 he produced a vaccine against rabies. Pasteur invented the process of pasteurization, to help prevent the spread of disease through milk and other foods.
# ---
# In 1847, Hungarian physician Ignác Fülöp Semmelweis dramatically reduced the occurrency of puerperal fever by simply requiring physicians to wash their hands before attending to women in childbirth. This discovery predated the germ theory of disease. However, Semmelweis' findings were not appreciated by his contemporaries and came into use only with discoveries by British surgeon Joseph Lister, who in 1865 proved the principles of antisepsis. Lister's work was based on the important findings by French biologist Louis Pasteur. Pasteur was able to link microorganisms with disease, revolutionizing medicine. He also devised one of the most important methods in preventive medicine, when in 1880 he produced a vaccine against rabies. Pasteur invented the process of pasteurization, to help prevent the spread of disease through milk and other foods.
# ---

# %% [markdown]
# Let’s finish with a final few questions.

# %%
query = "what was the war of currents?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('The war of currents is a term used to refer to a series of events that '
#  'occurred in the late 19th and early 20th centuries. The most famous of these '
#  'events was the Battle of')

# %%
query = "who was the first person on the moon?"
context = query_pinecone(query, top_k=10)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('The first person to go to the moon was Apollo 11. The Apollo 11 astronauts '
#  'landed on the moon in 1969. The Apollo 11 astronauts landed on the moon in '
#  '1969. The Apollo 11 astronauts')

# %%
query = "what was NASAs most expensive project?"
context = query_pinecone(query, top_k=3)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ("I'm not sure if this counts as a project, but I think it's worth noting that "
#  'the NASAs budget for the first year of its existence was about $1.5 billion.')

# %% [markdown]
# As we can see, the model can generate some decent answers.

# %% [markdown]
# #### Add a few more questions

# %%
query = "What is artificial intelligence?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
answer = generate_answer(query)
print(f"Question: {query.split('question: ')[1].split(' context:')[0]}")
print(f"Answer: {answer}")
# Out:
# ('Artificial intelligence is a term used to describe the ability of a computer '
#  "to do things that humans can't do. For example, if you want to make a "
#  'computer program that can do math')
# Question: What is artificial intelligence?
# Answer: None

# %%
# Example 2
query = "How does photosynthesis work?"
context = query_pinecone(query, top_k=5)
query_formatted = format_query(query, context["matches"])
answer = generate_answer(query_formatted)
print(f"Q: {query}")
print(f"A: {answer}\n")

# Example 3
query = "Explain the theory of relativity"
context = query_pinecone(query, top_k=5)
query_formatted = format_query(query, context["matches"])
answer = generate_answer(query_formatted)
print(f"Q: {query}")
print(f"A: {answer}")
# Out:
# ('Photosynthesis is the process of converting sunlight into chemical energy. '
#  "It's not a single process, it's a series of steps. The first step is to "
#  'convert the sunlight into chemical energy.')
# Q: How does photosynthesis work?
# A: None
#
# ('The theory of relativity is the theory that the speed of light is the same '
#  'in all inertial reference frames. This means that the speed of light is the '
#  'same in all inertial reference frames')
# Q: Explain the theory of relativity
# A: None
